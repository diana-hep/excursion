# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np
np.warnings.filterwarnings('ignore')
import datetime
import os

import excursion

import excursion.testcases.oned_fast as scandetails
import excursion.optimize

from excursion.utils import point_entropy, mesh2points, points2mesh, values2mesh

import excursion.plotting.onedim as plots
import excursion.utils as utils

# %%
for func in scandetails.truth_functions:
    plt.plot(scandetails.plotX.ravel(),func(scandetails.plotX).ravel(), label=str(func))
    
for thr in scandetails.thresholds:
    plt.hlines(thr, np.min(scandetails.plotX),np.max(scandetails.plotX), colors = 'red', label=str(thr))

# %%
import torch
X_grid = torch.arange(-1,1,0.1)
y_true = func(scandetails.plotX).ravel()

# %% [markdown]
# ### 1) GP model specification
# prior:
#  - RBF kernel
#  - constant mean

# %%
import gpytorch

# %%
# simplest form of GP model RBF with constant mean prior, exact inference
class ExactGPModel(gpytorch.models.ExactGP):
    def __init__(self, train_x, train_y, likelihood):
        super(ExactGPModel, self).__init__(train_x, train_y, likelihood)
        self.mean_module = gpytorch.means.ConstantMean()
        self.covar_module = gpytorch.kernels.ScaleKernel(\
                            gpytorch.kernels.RBFKernel(\
                            lengthscale_constraint=gpytorch.constraints.GreaterThan(lower_bound=0.1)
                            ))
                                                      

    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

# %% [markdown]
# ### 2) Likelihood / observational model
#
# excursion: $\epsilon = 0$

# %%
likelihood = gpytorch.likelihoods.FixedNoiseGaussianLikelihood(noise=torch.tensor([0.]))

# %% [markdown]
# ### 3) Model

# %% [markdown]
# initialization: $x_0$ (2 points)

# %%
np.random.seed(1)
X = torch.from_numpy(\
          np.random.uniform(scandetails.plot_rangedef[:,0],scandetails.plot_rangedef[:,1], size = (2,)) )

y_list = torch.from_numpy(\
          np.array([scandetails.truth_functions[0](np.asarray([x]))[0] for x in X]) )

print('X_0 = ', X)
print('f(X_0) = ', y_list)
# Out:
# X_0 =  tensor([-0.1660,  0.4406], dtype=torch.float64)
# f(X_0) =  tensor([14.1128,  2.4481], dtype=torch.float64)

# %%
for i in range(len(X_grid)):
    if(abs(X_grid[i]-0.4406)<0.01 ):
        print('index',i)
        
len(X_grid)
# Out:
# 20

# %% [markdown]
# ### 4) Acquisition of new points maximizing info gain: testing

# %%
#call info gain
#sys.path.insert(0, '/home/irina/Documents/PROJECTS/excursion/excursion/optimize/')
#import optimize.core as optimizecore
#info_gain_candidate = optimizecore.info_gain_gpytorch(xcandidate, gps, thresholds, X_grid)
#print('info gain of xcandidate = '+str(xcandidate[0])+' given training set :', info_gain_candidate)

# %%
#sys.path.insert(0, '/home/irina/Documents/PROJECTS/excursion/excursion/optimize')
#import optimize as optimize
#import imp
#imp.reload(optimize)
#imp.reload(optimizecore)
#newx, acqvals = optimize.gridsearch_gpytorch(gps, X, scandetails)

# %% [markdown]
# ### 5) Contour approximation

# %%
def plot_and_save(workdir, index, *args):
    fig, axarr = plt.subplots(1, 2)
    fig.set_size_inches(9.5, 3.5)
    gp = args[0]
    plots.plot_gpytorch(axarr,gp, likelihood, X, y_list, scandetails)
    plt.tight_layout()
    plt.savefig(os.path.join(workdir,'update_{}.png'.format(str(index).zfill(3))), bbox_inches = 'tight')
    plt.show()

# %%
import imp
imp.reload(plots)
imp.reload(utils)

import datetime
workdir = datetime.datetime.now().strftime('%Y-%m-%d-%H-%M-%S-2dmulti')
os.mkdir(workdir)

N_UPDATES = 10
torch.save(X_grid,'X.dat')


######## DEBUG
def set_parameters(gp, i):
    if(i==0):
        gp.covar_module.outputscale =  10.1
        gp.covar_module.base_kernel.lengthscale = 0.411
    elif(i==1):
        gp.covar_module.outputscale = 11.7
        gp.covar_module.base_kernel.lengthscale = 0.68
    elif(i==2):
        gp.covar_module.outputscale = 11.4
        gp.covar_module.base_kernel.lengthscale = 0.49
    elif(i==3):
        gp.covar_module.outputscale = 10.8
        gp.covar_module.base_kernel.lengthscale = 0.32
    elif(i==4):
        gp.covar_module.outputscale = 10.3
        gp.covar_module.base_kernel.lengthscale = 0.29
    elif(i==5):
        gp.covar_module.outputscale = 10.0
        gp.covar_module.base_kernel.lengthscale = 0.29
    elif(i==6):
        gp.covar_module.outputscale = 10.3
        gp.covar_module.base_kernel.lengthscale = 0.22
    elif(i==7):
        gp.covar_module.outputscale = 10.3
        gp.covar_module.base_kernel.lengthscale = 0.22
    elif(i==8):
        gp.covar_module.outputscale = 10.2
        gp.covar_module.base_kernel.lengthscale = 0.216
    elif(i==9):
        gp.covar_module.outputscale = 9.77
        gp.covar_module.base_kernel.lengthscale = 0.214
    
    
########

for index in range(N_UPDATES):
    model = ExactGPModel(X, y_list, likelihood)
    gps = [model]
    #set_parameters(gps[0], index)
    
    print('*****iter******* ', index)
    print(gps[0].covar_module.outputscale, gps[0].covar_module.base_kernel.lengthscale)
    #training the model with new points and optimize hyperparams
    excursion.optimize.train_hyperparameters(gps[0], X, y_list, likelihood, optimizer='Adam')
    
    #now plot and obtain next point that maximizes info gain
    plot_and_save(workdir, index, gps[0], likelihood, X, y_list, scandetails)

    newx, acqvals = excursion.optimize.gridsearch_gpytorch(gps, X, scandetails)
    torch.save(acqvals,'acq_'+str(index)+'_gpytorch.dat')
    
    newys_list = [scandetails.truth_functions[0](np.asarray([newx]))]
    
    #update training points
    for i,newys in enumerate(newys_list):
        i_eff = i + len(y_list)
        print('Iteration {}. Evaluted function {} to values: {} \n'.format(index, i_eff,newys))
        y_list = torch.cat( (y_list, torch.tensor(newys[0]) ), -1 )

    X = torch.from_numpy( np.concatenate( [X, np.array([newx[0]])] ) )
# Out:
# *****iter*******  0
# tensor(0.6931, grad_fn=<SoftplusBackward>) tensor([[0.7931]], grad_fn=<AddBackward0>)
# inside optimizer: i =  0
# Iter 1/100 - Loss: 125.618   lengthscale: 0.793 outputscale: 0.693  noise: 0.000
# Iter 1/100 - Loss: 116.796   lengthscale: 0.768 outputscale: 0.716  noise: 0.000
# Iter 1/100 - Loss: 108.336   lengthscale: 0.744 outputscale: 0.743  noise: 0.000
# Iter 1/100 - Loss: 100.557   lengthscale: 0.722 outputscale: 0.773  noise: 0.000
# Iter 1/100 - Loss: 93.379   lengthscale: 0.703 outputscale: 0.807  noise: 0.000
# Iter 1/100 - Loss: 86.752   lengthscale: 0.684 outputscale: 0.843  noise: 0.000
# Iter 1/100 - Loss: 80.634   lengthscale: 0.668 outputscale: 0.883  noise: 0.000
# Iter 1/100 - Loss: 74.987   lengthscale: 0.652 outputscale: 0.927  noise: 0.000
# Iter 1/100 - Loss: 69.775   lengthscale: 0.638 outputscale: 0.974  noise: 0.000
# Iter 1/100 - Loss: 64.966   lengthscale: 0.625 outputscale: 1.023  noise: 0.000
# Iter 1/100 - Loss: 60.526   lengthscale: 0.612 outputscale: 1.076  noise: 0.000
# Iter 1/100 - Loss: 56.426   lengthscale: 0.601 outputscale: 1.132  noise: 0.000
# Iter 1/100 - Loss: 52.637   lengthscale: 0.589 outputscale: 1.191  noise: 0.000
# Iter 1/100 - Loss: 49.133   lengthscale: 0.578 outputscale: 1.252  noise: 0.000
# Iter 1/100 - Loss: 45.889   lengthscale: 0.567 outputscale: 1.317  noise: 0.000
# Iter 1/100 - Loss: 42.883   lengthscale: 0.557 outputscale: 1.384  noise: 0.000
# Iter 1/100 - Loss: 40.093   lengthscale: 0.547 outputscale: 1.453  noise: 0.000
# Iter 1/100 - Loss: 37.500   lengthscale: 0.537 outputscale: 1.526  noise: 0.000
# Iter 1/100 - Loss: 35.088   lengthscale: 0.527 outputscale: 1.601  noise: 0.000
# Iter 1/100 - Loss: 32.841   lengthscale: 0.517 outputscale: 1.679  noise: 0.000
# inside optimizer: i =  1
# Iter 2/100 - Loss: 30.745   lengthscale: 0.507 outputscale: 1.759  noise: 0.000
# Iter 2/100 - Loss: 28.786   lengthscale: 0.497 outputscale: 1.842  noise: 0.000
# Iter 2/100 - Loss: 26.953   lengthscale: 0.487 outputscale: 1.928  noise: 0.000
# Iter 2/100 - Loss: 25.235   lengthscale: 0.478 outputscale: 2.017  noise: 0.000
# Iter 2/100 - Loss: 23.624   lengthscale: 0.468 outputscale: 2.108  noise: 0.000
# Iter 2/100 - Loss: 22.110   lengthscale: 0.458 outputscale: 2.201  noise: 0.000
# Iter 2/100 - Loss: 20.686   lengthscale: 0.448 outputscale: 2.297  noise: 0.000
# Iter 2/100 - Loss: 19.345   lengthscale: 0.438 outputscale: 2.395  noise: 0.000
# Iter 2/100 - Loss: 18.082   lengthscale: 0.428 outputscale: 2.495  noise: 0.000
# Iter 2/100 - Loss: 16.892   lengthscale: 0.418 outputscale: 2.596  noise: 0.000
# Iter 2/100 - Loss: 15.771   lengthscale: 0.408 outputscale: 2.698  noise: 0.000
# Iter 2/100 - Loss: 14.717   lengthscale: 0.397 outputscale: 2.801  noise: 0.000
# Iter 2/100 - Loss: 13.727   lengthscale: 0.386 outputscale: 2.904  noise: 0.000
# Iter 2/100 - Loss: 12.800   lengthscale: 0.375 outputscale: 3.006  noise: 0.000
# Iter 2/100 - Loss: 11.936   lengthscale: 0.364 outputscale: 3.107  noise: 0.000
# Iter 2/100 - Loss: 11.136   lengthscale: 0.353 outputscale: 3.205  noise: 0.000
# Iter 2/100 - Loss: 10.402   lengthscale: 0.342 outputscale: 3.301  noise: 0.000
# Iter 2/100 - Loss: 9.734   lengthscale: 0.332 outputscale: 3.393  noise: 0.000
# Iter 2/100 - Loss: 9.133   lengthscale: 0.321 outputscale: 3.482  noise: 0.000
# Iter 2/100 - Loss: 8.600   lengthscale: 0.312 outputscale: 3.567  noise: 0.000
# inside optimizer: i =  2
# Iter 3/100 - Loss: 8.132   lengthscale: 0.303 outputscale: 3.650  noise: 0.000
# Iter 3/100 - Loss: 7.725   lengthscale: 0.295 outputscale: 3.731  noise: 0.000
# Iter 3/100 - Loss: 7.372   lengthscale: 0.287 outputscale: 3.812  noise: 0.000
# Iter 3/100 - Loss: 7.065   lengthscale: 0.281 outputscale: 3.894  noise: 0.000
# Iter 3/100 - Loss: 6.797   lengthscale: 0.276 outputscale: 3.980  noise: 0.000
# Iter 3/100 - Loss: 6.561   lengthscale: 0.271 outputscale: 4.071  noise: 0.000
# Iter 3/100 - Loss: 6.349   lengthscale: 0.266 outputscale: 4.168  noise: 0.000
# Iter 3/100 - Loss: 6.157   lengthscale: 0.263 outputscale: 4.273  noise: 0.000
# Iter 3/100 - Loss: 5.981   lengthscale: 0.259 outputscale: 4.387  noise: 0.000
# Iter 3/100 - Loss: 5.818   lengthscale: 0.256 outputscale: 4.511  noise: 0.000
# Iter 3/100 - Loss: 5.665   lengthscale: 0.253 outputscale: 4.646  noise: 0.000
# Iter 3/100 - Loss: 5.521   lengthscale: 0.250 outputscale: 4.792  noise: 0.000
# Iter 3/100 - Loss: 5.384   lengthscale: 0.247 outputscale: 4.951  noise: 0.000
# Iter 3/100 - Loss: 5.254   lengthscale: 0.245 outputscale: 5.122  noise: 0.000
# Iter 3/100 - Loss: 5.129   lengthscale: 0.242 outputscale: 5.305  noise: 0.000
# Iter 3/100 - Loss: 5.011   lengthscale: 0.240 outputscale: 5.502  noise: 0.000
# Iter 3/100 - Loss: 4.898   lengthscale: 0.238 outputscale: 5.711  noise: 0.000
# Iter 3/100 - Loss: 4.790   lengthscale: 0.235 outputscale: 5.934  noise: 0.000
# Iter 3/100 - Loss: 4.687   lengthscale: 0.233 outputscale: 6.168  noise: 0.000
# Iter 3/100 - Loss: 4.590   lengthscale: 0.231 outputscale: 6.415  noise: 0.000
# inside optimizer: i =  3
# Iter 4/100 - Loss: 4.497   lengthscale: 0.229 outputscale: 6.674  noise: 0.000
# Iter 4/100 - Loss: 4.409   lengthscale: 0.227 outputscale: 6.944  noise: 0.000
# Iter 4/100 - Loss: 4.326   lengthscale: 0.225 outputscale: 7.225  noise: 0.000
# Iter 4/100 - Loss: 4.248   lengthscale: 0.223 outputscale: 7.518  noise: 0.000
# Iter 4/100 - Loss: 4.174   lengthscale: 0.221 outputscale: 7.821  noise: 0.000
# Iter 4/100 - Loss: 4.105   lengthscale: 0.220 outputscale: 8.135  noise: 0.000
# Iter 4/100 - Loss: 4.039   lengthscale: 0.218 outputscale: 8.461  noise: 0.000
# Iter 4/100 - Loss: 3.978   lengthscale: 0.216 outputscale: 8.797  noise: 0.000
# Iter 4/100 - Loss: 3.920   lengthscale: 0.214 outputscale: 9.144  noise: 0.000
# Iter 4/100 - Loss: 3.866   lengthscale: 0.213 outputscale: 9.503  noise: 0.000
# Iter 4/100 - Loss: 3.815   lengthscale: 0.211 outputscale: 9.873  noise: 0.000
# Iter 4/100 - Loss: 3.767   lengthscale: 0.209 outputscale: 10.254  noise: 0.000
# Iter 4/100 - Loss: 3.722   lengthscale: 0.208 outputscale: 10.649  noise: 0.000
# Iter 4/100 - Loss: 3.680   lengthscale: 0.206 outputscale: 11.045  noise: 0.000
# Iter 4/100 - Loss: 3.640   lengthscale: 0.206 outputscale: 11.486  noise: 0.000
# Iter 4/100 - Loss: 3.598   lengthscale: 0.194 outputscale: 11.888  noise: 0.000
# Iter 4/100 - Loss: 3.567   lengthscale: 0.192 outputscale: 12.286  noise: 0.000
# Iter 4/100 - Loss: 3.535   lengthscale: 0.191 outputscale: 12.740  noise: 0.000
# Iter 4/100 - Loss: 3.506   lengthscale: 0.190 outputscale: 13.199  noise: 0.000
# Iter 4/100 - Loss: 3.478   lengthscale: 0.189 outputscale: 13.671  noise: 0.000
# inside optimizer: i =  4
# Iter 5/100 - Loss: 3.452   lengthscale: 0.188 outputscale: 14.151  noise: 0.000
# Iter 5/100 - Loss: 3.428   lengthscale: 0.186 outputscale: 14.642  noise: 0.000
# Iter 5/100 - Loss: 3.406   lengthscale: 0.185 outputscale: 15.143  noise: 0.000
# Iter 5/100 - Loss: 3.386   lengthscale: 0.184 outputscale: 15.652  noise: 0.000
# Iter 5/100 - Loss: 3.367   lengthscale: 0.183 outputscale: 16.170  noise: 0.000
# Iter 5/100 - Loss: 3.349   lengthscale: 0.182 outputscale: 16.696  noise: 0.000
# Iter 5/100 - Loss: 3.333   lengthscale: 0.181 outputscale: 17.230  noise: 0.000
# Iter 5/100 - Loss: 3.318   lengthscale: 0.180 outputscale: 17.776  noise: 0.000
# Iter 5/100 - Loss: 3.304   lengthscale: 0.179 outputscale: 18.351  noise: 0.000
# Iter 5/100 - Loss: 3.290   lengthscale: 0.177 outputscale: 18.936  noise: 0.000
# Iter 5/100 - Loss: 3.278   lengthscale: 0.176 outputscale: 19.514  noise: 0.000
# Iter 5/100 - Loss: 3.268   lengthscale: 0.175 outputscale: 20.084  noise: 0.000
# Iter 5/100 - Loss: 3.258   lengthscale: 0.174 outputscale: 20.655  noise: 0.000
# Iter 5/100 - Loss: 3.250   lengthscale: 0.173 outputscale: 21.221  noise: 0.000
# Iter 5/100 - Loss: 3.242   lengthscale: 0.172 outputscale: 21.785  noise: 0.000
# Iter 5/100 - Loss: 3.235   lengthscale: 0.171 outputscale: 22.344  noise: 0.000
# Iter 5/100 - Loss: 3.229   lengthscale: 0.170 outputscale: 22.898  noise: 0.000
# Iter 5/100 - Loss: 3.223   lengthscale: 0.169 outputscale: 23.445  noise: 0.000
# Iter 5/100 - Loss: 3.218   lengthscale: 0.168 outputscale: 23.985  noise: 0.000
# Iter 5/100 - Loss: 3.213   lengthscale: 0.167 outputscale: 24.516  noise: 0.000
# inside optimizer: i =  5
# Iter 6/100 - Loss: 3.209   lengthscale: 0.166 outputscale: 25.037  noise: 0.000
# Iter 6/100 - Loss: 3.206   lengthscale: 0.165 outputscale: 25.545  noise: 0.000
# Iter 6/100 - Loss: 3.203   lengthscale: 0.164 outputscale: 26.042  noise: 0.000
# Iter 6/100 - Loss: 3.200   lengthscale: 0.163 outputscale: 26.524  noise: 0.000
# Iter 6/100 - Loss: 3.197   lengthscale: 0.162 outputscale: 26.992  noise: 0.000
# Iter 6/100 - Loss: 3.195   lengthscale: 0.161 outputscale: 27.444  noise: 0.000
# Iter 6/100 - Loss: 3.193   lengthscale: 0.160 outputscale: 27.879  noise: 0.000
# Iter 6/100 - Loss: 3.192   lengthscale: 0.159 outputscale: 28.298  noise: 0.000
# Iter 6/100 - Loss: 3.190   lengthscale: 0.158 outputscale: 28.698  noise: 0.000
# Iter 6/100 - Loss: 3.189   lengthscale: 0.157 outputscale: 29.081  noise: 0.000
# Iter 6/100 - Loss: 3.188   lengthscale: 0.156 outputscale: 29.444  noise: 0.000
# Iter 6/100 - Loss: 3.187   lengthscale: 0.156 outputscale: 29.790  noise: 0.000
# Iter 6/100 - Loss: 3.186   lengthscale: 0.155 outputscale: 30.115  noise: 0.000
# Iter 6/100 - Loss: 3.186   lengthscale: 0.154 outputscale: 30.424  noise: 0.000
# Iter 6/100 - Loss: 3.185   lengthscale: 0.153 outputscale: 30.712  noise: 0.000
# Iter 6/100 - Loss: 3.185   lengthscale: 0.152 outputscale: 30.984  noise: 0.000
# Iter 6/100 - Loss: 3.184   lengthscale: 0.151 outputscale: 31.237  noise: 0.000
# Iter 6/100 - Loss: 3.184   lengthscale: 0.151 outputscale: 31.474  noise: 0.000
# Iter 6/100 - Loss: 3.184   lengthscale: 0.150 outputscale: 31.692  noise: 0.000
# Iter 6/100 - Loss: 3.184   lengthscale: 0.149 outputscale: 31.897  noise: 0.000
# inside optimizer: i =  6
# Iter 7/100 - Loss: 3.183   lengthscale: 0.148 outputscale: 32.085  noise: 0.000
# Iter 7/100 - Loss: 3.183   lengthscale: 0.147 outputscale: 32.260  noise: 0.000
# Iter 7/100 - Loss: 3.183   lengthscale: 0.147 outputscale: 32.419  noise: 0.000
# Iter 7/100 - Loss: 3.183   lengthscale: 0.146 outputscale: 32.568  noise: 0.000
# Iter 7/100 - Loss: 3.183   lengthscale: 0.145 outputscale: 32.703  noise: 0.000
# Iter 7/100 - Loss: 3.183   lengthscale: 0.145 outputscale: 32.827  noise: 0.000
# Iter 7/100 - Loss: 3.183   lengthscale: 0.144 outputscale: 32.941  noise: 0.000
# Iter 7/100 - Loss: 3.183   lengthscale: 0.143 outputscale: 33.045  noise: 0.000
# Iter 7/100 - Loss: 3.183   lengthscale: 0.143 outputscale: 33.140  noise: 0.000
# Iter 7/100 - Loss: 3.183   lengthscale: 0.142 outputscale: 33.226  noise: 0.000
# Iter 7/100 - Loss: 3.183   lengthscale: 0.141 outputscale: 33.305  noise: 0.000
# Iter 7/100 - Loss: 3.182   lengthscale: 0.141 outputscale: 33.377  noise: 0.000
# Iter 7/100 - Loss: 3.182   lengthscale: 0.140 outputscale: 33.442  noise: 0.000
# Iter 7/100 - Loss: 3.182   lengthscale: 0.140 outputscale: 33.501  noise: 0.000
# Iter 7/100 - Loss: 3.182   lengthscale: 0.139 outputscale: 33.555  noise: 0.000
# Iter 7/100 - Loss: 3.182   lengthscale: 0.139 outputscale: 33.604  noise: 0.000
# Iter 7/100 - Loss: 3.182   lengthscale: 0.138 outputscale: 33.648  noise: 0.000
# Iter 7/100 - Loss: 3.182   lengthscale: 0.138 outputscale: 33.688  noise: 0.000
# Iter 7/100 - Loss: 3.182   lengthscale: 0.137 outputscale: 33.724  noise: 0.000
# Iter 7/100 - Loss: 3.182   lengthscale: 0.137 outputscale: 33.757  noise: 0.000
# inside optimizer: i =  7
# Iter 8/100 - Loss: 3.182   lengthscale: 0.136 outputscale: 33.787  noise: 0.000
# Iter 8/100 - Loss: 3.182   lengthscale: 0.136 outputscale: 33.814  noise: 0.000
# Iter 8/100 - Loss: 3.182   lengthscale: 0.136 outputscale: 33.838  noise: 0.000
# Iter 8/100 - Loss: 3.182   lengthscale: 0.135 outputscale: 33.860  noise: 0.000
# Iter 8/100 - Loss: 3.182   lengthscale: 0.135 outputscale: 33.880  noise: 0.000
# Iter 8/100 - Loss: 3.182   lengthscale: 0.134 outputscale: 33.898  noise: 0.000
# Iter 8/100 - Loss: 3.182   lengthscale: 0.134 outputscale: 33.914  noise: 0.000
# Iter 8/100 - Loss: 3.182   lengthscale: 0.133 outputscale: 33.928  noise: 0.000
# Iter 8/100 - Loss: 3.182   lengthscale: 0.133 outputscale: 33.941  noise: 0.000
# Iter 8/100 - Loss: 3.182   lengthscale: 0.132 outputscale: 33.952  noise: 0.000
# Iter 8/100 - Loss: 3.182   lengthscale: 0.132 outputscale: 33.962  noise: 0.000
# Iter 8/100 - Loss: 3.182   lengthscale: 0.131 outputscale: 33.970  noise: 0.000
# Iter 8/100 - Loss: 3.182   lengthscale: 0.131 outputscale: 33.978  noise: 0.000
# Iter 8/100 - Loss: 3.182   lengthscale: 0.130 outputscale: 33.984  noise: 0.000
# Iter 8/100 - Loss: 3.182   lengthscale: 0.130 outputscale: 33.989  noise: 0.000
# Iter 8/100 - Loss: 3.182   lengthscale: 0.129 outputscale: 33.993  noise: 0.000
# Iter 8/100 - Loss: 3.182   lengthscale: 0.129 outputscale: 33.996  noise: 0.000
# Iter 8/100 - Loss: 3.182   lengthscale: 0.128 outputscale: 33.998  noise: 0.000
# Iter 8/100 - Loss: 3.182   lengthscale: 0.128 outputscale: 34.001  noise: 0.000
# Iter 8/100 - Loss: 3.182   lengthscale: 0.127 outputscale: 34.002  noise: 0.000
# inside optimizer: i =  8
# Iter 9/100 - Loss: 3.182   lengthscale: 0.127 outputscale: 34.004  noise: 0.000
# Iter 9/100 - Loss: 3.182   lengthscale: 0.126 outputscale: 34.005  noise: 0.000
# Iter 9/100 - Loss: 3.182   lengthscale: 0.126 outputscale: 34.007  noise: 0.000
# Iter 9/100 - Loss: 3.182   lengthscale: 0.125 outputscale: 34.008  noise: 0.000
# Iter 9/100 - Loss: 3.182   lengthscale: 0.125 outputscale: 34.009  noise: 0.000
# Iter 9/100 - Loss: 3.182   lengthscale: 0.125 outputscale: 34.009  noise: 0.000
# Iter 9/100 - Loss: 3.182   lengthscale: 0.124 outputscale: 34.010  noise: 0.000
# Iter 9/100 - Loss: 3.182   lengthscale: 0.124 outputscale: 34.011  noise: 0.000
# Iter 9/100 - Loss: 3.182   lengthscale: 0.123 outputscale: 34.012  noise: 0.000
# Iter 9/100 - Loss: 3.182   lengthscale: 0.123 outputscale: 34.012  noise: 0.000
# Iter 9/100 - Loss: 3.182   lengthscale: 0.122 outputscale: 34.013  noise: 0.000
# Iter 9/100 - Loss: 3.182   lengthscale: 0.122 outputscale: 34.013  noise: 0.000
# Iter 9/100 - Loss: 3.182   lengthscale: 0.121 outputscale: 34.013  noise: 0.000
# Iter 9/100 - Loss: 3.182   lengthscale: 0.121 outputscale: 34.014  noise: 0.000
# Iter 9/100 - Loss: 3.182   lengthscale: 0.121 outputscale: 34.014  noise: 0.000
# Iter 9/100 - Loss: 3.182   lengthscale: 0.120 outputscale: 34.014  noise: 0.000
# Iter 9/100 - Loss: 3.182   lengthscale: 0.120 outputscale: 34.015  noise: 0.000
# Iter 9/100 - Loss: 3.182   lengthscale: 0.119 outputscale: 34.014  noise: 0.000
# Iter 9/100 - Loss: 3.182   lengthscale: 0.119 outputscale: 34.015  noise: 0.000
# Iter 9/100 - Loss: 3.182   lengthscale: 0.119 outputscale: 34.015  noise: 0.000
# inside optimizer: i =  9
# Iter 10/100 - Loss: 3.182   lengthscale: 0.118 outputscale: 34.016  noise: 0.000
# Iter 10/100 - Loss: 3.182   lengthscale: 0.118 outputscale: 34.015  noise: 0.000
# Iter 10/100 - Loss: 3.182   lengthscale: 0.117 outputscale: 34.016  noise: 0.000
# Iter 10/100 - Loss: 3.182   lengthscale: 0.117 outputscale: 34.015  noise: 0.000
# Iter 10/100 - Loss: 3.182   lengthscale: 0.117 outputscale: 34.016  noise: 0.000
# Iter 10/100 - Loss: 3.182   lengthscale: 0.116 outputscale: 34.015  noise: 0.000
# Iter 10/100 - Loss: 3.182   lengthscale: 0.116 outputscale: 34.017  noise: 0.000
# Iter 10/100 - Loss: 3.182   lengthscale: 0.116 outputscale: 34.016  noise: 0.000
# Iter 10/100 - Loss: 3.182   lengthscale: 0.115 outputscale: 34.016  noise: 0.000
# Iter 10/100 - Loss: 3.182   lengthscale: 0.115 outputscale: 34.016  noise: 0.000
# Iter 10/100 - Loss: 3.182   lengthscale: 0.115 outputscale: 34.016  noise: 0.000
# Iter 10/100 - Loss: 3.182   lengthscale: 0.114 outputscale: 34.016  noise: 0.000
# Iter 10/100 - Loss: 3.182   lengthscale: 0.114 outputscale: 34.016  noise: 0.000
# Iter 10/100 - Loss: 3.182   lengthscale: 0.114 outputscale: 34.016  noise: 0.000
# Iter 10/100 - Loss: 3.182   lengthscale: 0.113 outputscale: 34.016  noise: 0.000
# Iter 10/100 - Loss: 3.182   lengthscale: 0.113 outputscale: 34.016  noise: 0.000
# Iter 10/100 - Loss: 3.182   lengthscale: 0.113 outputscale: 34.016  noise: 0.000
# Iter 10/100 - Loss: 3.182   lengthscale: 0.112 outputscale: 34.016  noise: 0.000
# Iter 10/100 - Loss: 3.182   lengthscale: 0.112 outputscale: 34.016  noise: 0.000
# Iter 10/100 - Loss: 3.182   lengthscale: 0.112 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  10
# Iter 11/100 - Loss: 3.182   lengthscale: 0.111 outputscale: 34.016  noise: 0.000
# Iter 11/100 - Loss: 3.182   lengthscale: 0.111 outputscale: 34.016  noise: 0.000
# Iter 11/100 - Loss: 3.182   lengthscale: 0.111 outputscale: 34.016  noise: 0.000
# Iter 11/100 - Loss: 3.182   lengthscale: 0.111 outputscale: 34.016  noise: 0.000
# Iter 11/100 - Loss: 3.182   lengthscale: 0.110 outputscale: 34.016  noise: 0.000
# Iter 11/100 - Loss: 3.182   lengthscale: 0.110 outputscale: 34.016  noise: 0.000
# Iter 11/100 - Loss: 3.182   lengthscale: 0.110 outputscale: 34.016  noise: 0.000
# Iter 11/100 - Loss: 3.182   lengthscale: 0.109 outputscale: 34.016  noise: 0.000
# Iter 11/100 - Loss: 3.182   lengthscale: 0.109 outputscale: 34.016  noise: 0.000
# Iter 11/100 - Loss: 3.182   lengthscale: 0.109 outputscale: 34.016  noise: 0.000
# Iter 11/100 - Loss: 3.182   lengthscale: 0.109 outputscale: 34.016  noise: 0.000
# Iter 11/100 - Loss: 3.182   lengthscale: 0.108 outputscale: 34.016  noise: 0.000
# Iter 11/100 - Loss: 3.182   lengthscale: 0.108 outputscale: 34.016  noise: 0.000
# Iter 11/100 - Loss: 3.182   lengthscale: 0.108 outputscale: 34.016  noise: 0.000
# Iter 11/100 - Loss: 3.182   lengthscale: 0.108 outputscale: 34.016  noise: 0.000
# Iter 11/100 - Loss: 3.182   lengthscale: 0.107 outputscale: 34.016  noise: 0.000
# Iter 11/100 - Loss: 3.182   lengthscale: 0.107 outputscale: 34.016  noise: 0.000
# Iter 11/100 - Loss: 3.182   lengthscale: 0.107 outputscale: 34.017  noise: 0.000
# Iter 11/100 - Loss: 3.182   lengthscale: 0.107 outputscale: 34.017  noise: 0.000
# Iter 11/100 - Loss: 3.182   lengthscale: 0.107 outputscale: 34.017  noise: 0.000
# inside optimizer: i =  11
# Iter 12/100 - Loss: 3.182   lengthscale: 0.106 outputscale: 34.017  noise: 0.000
# Iter 12/100 - Loss: 3.182   lengthscale: 0.106 outputscale: 34.017  noise: 0.000
# Iter 12/100 - Loss: 3.182   lengthscale: 0.106 outputscale: 34.017  noise: 0.000
# Iter 12/100 - Loss: 3.182   lengthscale: 0.106 outputscale: 34.017  noise: 0.000
# Iter 12/100 - Loss: 3.182   lengthscale: 0.106 outputscale: 34.017  noise: 0.000
# Iter 12/100 - Loss: 3.182   lengthscale: 0.105 outputscale: 34.017  noise: 0.000
# Iter 12/100 - Loss: 3.182   lengthscale: 0.105 outputscale: 34.016  noise: 0.000
# Iter 12/100 - Loss: 3.182   lengthscale: 0.105 outputscale: 34.016  noise: 0.000
# Iter 12/100 - Loss: 3.182   lengthscale: 0.105 outputscale: 34.017  noise: 0.000
# Iter 12/100 - Loss: 3.182   lengthscale: 0.105 outputscale: 34.016  noise: 0.000
# Iter 12/100 - Loss: 3.182   lengthscale: 0.104 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  12
# Iter 13/100 - Loss: 3.182   lengthscale: 0.104 outputscale: 34.016  noise: 0.000
# Iter 13/100 - Loss: 3.182   lengthscale: 0.104 outputscale: 34.016  noise: 0.000
# Iter 13/100 - Loss: 3.182   lengthscale: 0.104 outputscale: 34.016  noise: 0.000
# Iter 13/100 - Loss: 3.182   lengthscale: 0.104 outputscale: 34.016  noise: 0.000
# Iter 13/100 - Loss: 3.182   lengthscale: 0.104 outputscale: 34.016  noise: 0.000
# Iter 13/100 - Loss: 3.182   lengthscale: 0.104 outputscale: 34.016  noise: 0.000
# Iter 13/100 - Loss: 3.182   lengthscale: 0.103 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  13
# Iter 14/100 - Loss: 3.182   lengthscale: 0.103 outputscale: 34.016  noise: 0.000
# Iter 14/100 - Loss: 3.182   lengthscale: 0.103 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  14
# Iter 15/100 - Loss: 3.182   lengthscale: 0.103 outputscale: 34.016  noise: 0.000
# Iter 15/100 - Loss: 3.182   lengthscale: 0.103 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  15
# Iter 16/100 - Loss: 3.182   lengthscale: 0.103 outputscale: 34.016  noise: 0.000
# Iter 16/100 - Loss: 3.182   lengthscale: 0.103 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  16
# Iter 17/100 - Loss: 3.182   lengthscale: 0.103 outputscale: 34.016  noise: 0.000
# Iter 17/100 - Loss: 3.182   lengthscale: 0.103 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  17
# Iter 18/100 - Loss: 3.182   lengthscale: 0.103 outputscale: 34.016  noise: 0.000
# Iter 18/100 - Loss: 3.182   lengthscale: 0.103 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  18
# Iter 19/100 - Loss: 3.182   lengthscale: 0.103 outputscale: 34.016  noise: 0.000
# Iter 19/100 - Loss: 3.182   lengthscale: 0.103 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  19
# Iter 20/100 - Loss: 3.182   lengthscale: 0.103 outputscale: 34.016  noise: 0.000
# Iter 20/100 - Loss: 3.182   lengthscale: 0.103 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  20
# Iter 21/100 - Loss: 3.182   lengthscale: 0.103 outputscale: 34.016  noise: 0.000
# Iter 21/100 - Loss: 3.182   lengthscale: 0.103 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  21
# Iter 22/100 - Loss: 3.182   lengthscale: 0.103 outputscale: 34.016  noise: 0.000
# Iter 22/100 - Loss: 3.182   lengthscale: 0.103 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  22
# Iter 23/100 - Loss: 3.182   lengthscale: 0.103 outputscale: 34.016  noise: 0.000
# Iter 23/100 - Loss: 3.182   lengthscale: 0.103 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  23
# Iter 24/100 - Loss: 3.182   lengthscale: 0.103 outputscale: 34.016  noise: 0.000
# Iter 24/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  24
# Iter 25/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# Iter 25/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  25
# Iter 26/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# Iter 26/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  26
# Iter 27/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# Iter 27/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  27
# Iter 28/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# Iter 28/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  28
# Iter 29/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# Iter 29/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  29
# Iter 30/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# Iter 30/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  30
# Iter 31/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# Iter 31/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  31
# Iter 32/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# Iter 32/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  32
# Iter 33/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# Iter 33/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  33
# Iter 34/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# Iter 34/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  34
# Iter 35/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# Iter 35/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  35
# Iter 36/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# Iter 36/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  36
# Iter 37/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# Iter 37/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  37
# Iter 38/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# Iter 38/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  38
# Iter 39/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  39
# Iter 40/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  40
# Iter 41/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  41
# Iter 42/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  42
# Iter 43/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  43
# Iter 44/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  44
# Iter 45/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  45
# Iter 46/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  46
# Iter 47/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  47
# Iter 48/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  48
# Iter 49/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  49
# Iter 50/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  50
# Iter 51/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  51
# Iter 52/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  52
# Iter 53/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  53
# Iter 54/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  54
# Iter 55/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  55
# Iter 56/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  56
# Iter 57/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  57
# Iter 58/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  58
# Iter 59/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  59
# Iter 60/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  60
# Iter 61/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  61
# Iter 62/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  62
# Iter 63/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  63
# Iter 64/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  64
# Iter 65/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  65
# Iter 66/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  66
# Iter 67/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  67
# Iter 68/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  68
# Iter 69/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  69
# Iter 70/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  70
# Iter 71/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  71
# Iter 72/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  72
# Iter 73/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  73
# Iter 74/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  74
# Iter 75/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  75
# Iter 76/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  76
# Iter 77/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  77
# Iter 78/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  78
# Iter 79/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  79
# Iter 80/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  80
# Iter 81/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  81
# Iter 82/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  82
# Iter 83/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  83
# Iter 84/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  84
# Iter 85/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  85
# Iter 86/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  86
# Iter 87/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  87
# Iter 88/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  88
# Iter 89/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  89
# Iter 90/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  90
# Iter 91/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  91
# Iter 92/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  92
# Iter 93/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  93
# Iter 94/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  94
# Iter 95/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  95
# Iter 96/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  96
# Iter 97/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  97
# Iter 98/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  98
# Iter 99/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# inside optimizer: i =  99
# Iter 100/100 - Loss: 3.182   lengthscale: 0.102 outputscale: 34.016  noise: 0.000
# info_gain
# taking new x. best non-existent index 0 [0.43434343]
# Iteration 0. Evaluted function 2 to values: [[2.64809925]]
#
# *****iter*******  1
# tensor(0.6931, grad_fn=<SoftplusBackward>) tensor([[0.7931]], grad_fn=<AddBackward0>)
# inside optimizer: i =  0
# Iter 1/100 - Loss: 161.848   lengthscale: 0.793 outputscale: 0.693  noise: 0.000
# Iter 1/100 - Loss: 141.800   lengthscale: 0.759 outputscale: 0.709  noise: 0.000
# Iter 1/100 - Loss: 132.017   lengthscale: 0.742 outputscale: 0.719  noise: 0.000
# Iter 1/100 - Loss: 122.641   lengthscale: 0.724 outputscale: 0.732  noise: 0.000
# Iter 1/100 - Loss: 114.000   lengthscale: 0.707 outputscale: 0.746  noise: 0.000
# Iter 1/100 - Loss: 106.007   lengthscale: 0.692 outputscale: 0.763  noise: 0.000
# Iter 1/100 - Loss: 98.603   lengthscale: 0.677 outputscale: 0.783  noise: 0.000
# Iter 1/100 - Loss: 91.737   lengthscale: 0.662 outputscale: 0.805  noise: 0.000
# Iter 1/100 - Loss: 85.363   lengthscale: 0.649 outputscale: 0.830  noise: 0.000
# Iter 1/100 - Loss: 79.446   lengthscale: 0.636 outputscale: 0.857  noise: 0.000
# Iter 1/100 - Loss: 73.950   lengthscale: 0.624 outputscale: 0.888  noise: 0.000
# Iter 1/100 - Loss: 68.849   lengthscale: 0.612 outputscale: 0.922  noise: 0.000
# Iter 1/100 - Loss: 64.114   lengthscale: 0.602 outputscale: 0.959  noise: 0.000
# Iter 1/100 - Loss: 59.723   lengthscale: 0.591 outputscale: 1.000  noise: 0.000
# Iter 1/100 - Loss: 55.653   lengthscale: 0.582 outputscale: 1.043  noise: 0.000
# Iter 1/100 - Loss: 51.884   lengthscale: 0.572 outputscale: 1.091  noise: 0.000
# Iter 1/100 - Loss: 48.394   lengthscale: 0.564 outputscale: 1.142  noise: 0.000
# Iter 1/100 - Loss: 45.165   lengthscale: 0.555 outputscale: 1.196  noise: 0.000
# Iter 1/100 - Loss: 42.177   lengthscale: 0.547 outputscale: 1.253  noise: 0.000
# Iter 1/100 - Loss: 39.414   lengthscale: 0.540 outputscale: 1.315  noise: 0.000
# inside optimizer: i =  1
# Iter 2/100 - Loss: 36.857   lengthscale: 0.533 outputscale: 1.379  noise: 0.000
# Iter 2/100 - Loss: 34.491   lengthscale: 0.525 outputscale: 1.447  noise: 0.000
# Iter 2/100 - Loss: 32.300   lengthscale: 0.519 outputscale: 1.518  noise: 0.000
# Iter 2/100 - Loss: 30.271   lengthscale: 0.512 outputscale: 1.593  noise: 0.000
# Iter 2/100 - Loss: 28.389   lengthscale: 0.505 outputscale: 1.671  noise: 0.000
# Iter 2/100 - Loss: 26.644   lengthscale: 0.499 outputscale: 1.752  noise: 0.000
# Iter 2/100 - Loss: 25.023   lengthscale: 0.493 outputscale: 1.837  noise: 0.000
# Iter 2/100 - Loss: 23.516   lengthscale: 0.486 outputscale: 1.925  noise: 0.000
# Iter 2/100 - Loss: 22.114   lengthscale: 0.480 outputscale: 2.017  noise: 0.000
# Iter 2/100 - Loss: 20.808   lengthscale: 0.474 outputscale: 2.112  noise: 0.000
# Iter 2/100 - Loss: 19.591   lengthscale: 0.468 outputscale: 2.212  noise: 0.000
# Iter 2/100 - Loss: 18.454   lengthscale: 0.462 outputscale: 2.315  noise: 0.000
# Iter 2/100 - Loss: 17.392   lengthscale: 0.456 outputscale: 2.421  noise: 0.000
# Iter 2/100 - Loss: 16.398   lengthscale: 0.450 outputscale: 2.532  noise: 0.000
# Iter 2/100 - Loss: 15.467   lengthscale: 0.444 outputscale: 2.647  noise: 0.000
# Iter 2/100 - Loss: 14.594   lengthscale: 0.438 outputscale: 2.767  noise: 0.000
# Iter 2/100 - Loss: 13.775   lengthscale: 0.432 outputscale: 2.890  noise: 0.000
# Iter 2/100 - Loss: 13.004   lengthscale: 0.427 outputscale: 3.018  noise: 0.000
# Iter 2/100 - Loss: 12.279   lengthscale: 0.421 outputscale: 3.150  noise: 0.000
# Iter 2/100 - Loss: 11.597   lengthscale: 0.415 outputscale: 3.287  noise: 0.000
# inside optimizer: i =  2
# Iter 3/100 - Loss: 10.953   lengthscale: 0.409 outputscale: 3.428  noise: 0.000
# Iter 3/100 - Loss: 10.347   lengthscale: 0.403 outputscale: 3.574  noise: 0.000
# Iter 3/100 - Loss: 9.774   lengthscale: 0.397 outputscale: 3.724  noise: 0.000
# Iter 3/100 - Loss: 9.234   lengthscale: 0.391 outputscale: 3.878  noise: 0.000
# Iter 3/100 - Loss: 8.723   lengthscale: 0.384 outputscale: 4.036  noise: 0.000
# Iter 3/100 - Loss: 8.242   lengthscale: 0.378 outputscale: 4.198  noise: 0.000
# Iter 3/100 - Loss: 7.788   lengthscale: 0.371 outputscale: 4.364  noise: 0.000
# Iter 3/100 - Loss: 7.360   lengthscale: 0.365 outputscale: 4.533  noise: 0.000
# Iter 3/100 - Loss: 6.957   lengthscale: 0.358 outputscale: 4.704  noise: 0.000
# Iter 3/100 - Loss: 6.579   lengthscale: 0.351 outputscale: 4.877  noise: 0.000
# Iter 3/100 - Loss: 6.225   lengthscale: 0.343 outputscale: 5.051  noise: 0.000
# Iter 3/100 - Loss: 5.894   lengthscale: 0.336 outputscale: 5.226  noise: 0.000
# Iter 3/100 - Loss: 5.584   lengthscale: 0.328 outputscale: 5.401  noise: 0.000
# Iter 3/100 - Loss: 5.297   lengthscale: 0.320 outputscale: 5.575  noise: 0.000
# Iter 3/100 - Loss: 5.030   lengthscale: 0.311 outputscale: 5.746  noise: 0.000
# Iter 3/100 - Loss: 4.782   lengthscale: 0.302 outputscale: 5.915  noise: 0.000
# Iter 3/100 - Loss: 4.553   lengthscale: 0.293 outputscale: 6.079  noise: 0.000
# Iter 3/100 - Loss: 4.340   lengthscale: 0.282 outputscale: 6.238  noise: 0.000
# Iter 3/100 - Loss: 4.141   lengthscale: 0.271 outputscale: 6.391  noise: 0.000
# Iter 3/100 - Loss: 3.954   lengthscale: 0.259 outputscale: 6.534  noise: 0.000
# inside optimizer: i =  3
# Iter 4/100 - Loss: 3.775   lengthscale: 0.245 outputscale: 6.666  noise: 0.000
# Iter 4/100 - Loss: 3.601   lengthscale: 0.230 outputscale: 6.780  noise: 0.000
# Iter 4/100 - Loss: 3.435   lengthscale: 0.213 outputscale: 6.873  noise: 0.000
# Iter 4/100 - Loss: 3.300   lengthscale: 0.199 outputscale: 6.947  noise: 0.000
# Iter 4/100 - Loss: 3.204   lengthscale: 0.188 outputscale: 7.019  noise: 0.000
# Iter 4/100 - Loss: 3.131   lengthscale: 0.181 outputscale: 7.097  noise: 0.000
# Iter 4/100 - Loss: 3.067   lengthscale: 0.176 outputscale: 7.192  noise: 0.000
# Iter 4/100 - Loss: 3.009   lengthscale: 0.171 outputscale: 7.306  noise: 0.000
# Iter 4/100 - Loss: 2.953   lengthscale: 0.167 outputscale: 7.443  noise: 0.000
# Iter 4/100 - Loss: 2.899   lengthscale: 0.163 outputscale: 7.605  noise: 0.000
# Iter 4/100 - Loss: 2.846   lengthscale: 0.160 outputscale: 7.793  noise: 0.000
# Iter 4/100 - Loss: 2.794   lengthscale: 0.157 outputscale: 8.006  noise: 0.000
# Iter 4/100 - Loss: 2.743   lengthscale: 0.154 outputscale: 8.243  noise: 0.000
# Iter 4/100 - Loss: 2.695   lengthscale: 0.152 outputscale: 8.503  noise: 0.000
# Iter 4/100 - Loss: 2.648   lengthscale: 0.150 outputscale: 8.784  noise: 0.000
# Iter 4/100 - Loss: 2.604   lengthscale: 0.149 outputscale: 9.083  noise: 0.000
# Iter 4/100 - Loss: 2.562   lengthscale: 0.147 outputscale: 9.398  noise: 0.000
# Iter 4/100 - Loss: 2.522   lengthscale: 0.146 outputscale: 9.727  noise: 0.000
# Iter 4/100 - Loss: 2.485   lengthscale: 0.145 outputscale: 10.070  noise: 0.000
# Iter 4/100 - Loss: 2.451   lengthscale: 0.144 outputscale: 10.425  noise: 0.000
# inside optimizer: i =  4
# Iter 5/100 - Loss: 2.419   lengthscale: 0.143 outputscale: 10.791  noise: 0.000
# Iter 5/100 - Loss: 2.389   lengthscale: 0.142 outputscale: 11.169  noise: 0.000
# Iter 5/100 - Loss: 2.361   lengthscale: 0.142 outputscale: 11.558  noise: 0.000
# Iter 5/100 - Loss: 2.336   lengthscale: 0.142 outputscale: 11.957  noise: 0.000
# Iter 5/100 - Loss: 2.312   lengthscale: 0.141 outputscale: 12.367  noise: 0.000
# Iter 5/100 - Loss: 2.290   lengthscale: 0.141 outputscale: 12.787  noise: 0.000
# Iter 5/100 - Loss: 2.269   lengthscale: 0.141 outputscale: 13.218  noise: 0.000
# Iter 5/100 - Loss: 2.250   lengthscale: 0.141 outputscale: 13.657  noise: 0.000
# Iter 5/100 - Loss: 2.233   lengthscale: 0.141 outputscale: 14.107  noise: 0.000
# Iter 5/100 - Loss: 2.217   lengthscale: 0.141 outputscale: 14.566  noise: 0.000
# Iter 5/100 - Loss: 2.202   lengthscale: 0.141 outputscale: 15.034  noise: 0.000
# Iter 5/100 - Loss: 2.188   lengthscale: 0.142 outputscale: 15.511  noise: 0.000
# Iter 5/100 - Loss: 2.175   lengthscale: 0.142 outputscale: 15.996  noise: 0.000
# Iter 5/100 - Loss: 2.164   lengthscale: 0.143 outputscale: 16.490  noise: 0.000
# Iter 5/100 - Loss: 2.153   lengthscale: 0.144 outputscale: 16.991  noise: 0.000
# Iter 5/100 - Loss: 2.143   lengthscale: 0.145 outputscale: 17.500  noise: 0.000
# Iter 5/100 - Loss: 2.134   lengthscale: 0.145 outputscale: 18.014  noise: 0.000
# Iter 5/100 - Loss: 2.125   lengthscale: 0.147 outputscale: 18.535  noise: 0.000
# Iter 5/100 - Loss: 2.118   lengthscale: 0.148 outputscale: 19.061  noise: 0.000
# Iter 5/100 - Loss: 2.111   lengthscale: 0.149 outputscale: 19.592  noise: 0.000
# inside optimizer: i =  5
# Iter 6/100 - Loss: 2.104   lengthscale: 0.150 outputscale: 20.126  noise: 0.000
# Iter 6/100 - Loss: 2.099   lengthscale: 0.151 outputscale: 20.663  noise: 0.000
# Iter 6/100 - Loss: 2.093   lengthscale: 0.153 outputscale: 21.202  noise: 0.000
# Iter 6/100 - Loss: 2.088   lengthscale: 0.154 outputscale: 21.742  noise: 0.000
# Iter 6/100 - Loss: 2.084   lengthscale: 0.156 outputscale: 22.286  noise: 0.000
# Iter 6/100 - Loss: 2.080   lengthscale: 0.157 outputscale: 22.826  noise: 0.000
# Iter 6/100 - Loss: 2.076   lengthscale: 0.159 outputscale: 23.403  noise: 0.000
# Iter 6/100 - Loss: 2.073   lengthscale: 0.159 outputscale: 23.968  noise: 0.000
# Iter 6/100 - Loss: 2.070   lengthscale: 0.161 outputscale: 24.484  noise: 0.000
# Iter 6/100 - Loss: 2.067   lengthscale: 0.163 outputscale: 25.027  noise: 0.000
# Iter 6/100 - Loss: 2.064   lengthscale: 0.162 outputscale: 25.595  noise: 0.000
# Iter 6/100 - Loss: 2.063   lengthscale: 0.164 outputscale: 26.045  noise: 0.000
# Iter 6/100 - Loss: 2.061   lengthscale: 0.167 outputscale: 26.596  noise: 0.000
# Iter 6/100 - Loss: 2.059   lengthscale: 0.169 outputscale: 27.131  noise: 0.000
# Iter 6/100 - Loss: 2.057   lengthscale: 0.172 outputscale: 27.659  noise: 0.000
# Iter 6/100 - Loss: 2.056   lengthscale: 0.174 outputscale: 28.177  noise: 0.000
# Iter 6/100 - Loss: 2.054   lengthscale: 0.176 outputscale: 28.687  noise: 0.000
# Iter 6/100 - Loss: 2.053   lengthscale: 0.178 outputscale: 29.188  noise: 0.000
# Iter 6/100 - Loss: 2.052   lengthscale: 0.181 outputscale: 29.683  noise: 0.000
# Iter 6/100 - Loss: 2.051   lengthscale: 0.183 outputscale: 30.181  noise: 0.000
# inside optimizer: i =  6
# Iter 7/100 - Loss: 2.051   lengthscale: 0.186 outputscale: 30.684  noise: 0.000
# Iter 7/100 - Loss: 2.050   lengthscale: 0.189 outputscale: 31.192  noise: 0.000
# Iter 7/100 - Loss: 2.049   lengthscale: 0.192 outputscale: 31.707  noise: 0.000
# Iter 7/100 - Loss: 2.048   lengthscale: 0.195 outputscale: 32.240  noise: 0.000
# Iter 7/100 - Loss: 2.048   lengthscale: 0.200 outputscale: 32.803  noise: 0.000
# Iter 7/100 - Loss: 2.047   lengthscale: 0.204 outputscale: 33.434  noise: 0.000
# Iter 7/100 - Loss: 2.046   lengthscale: 0.210 outputscale: 34.184  noise: 0.000
# Iter 7/100 - Loss: 2.045   lengthscale: 0.220 outputscale: 35.322  noise: 0.000
# Iter 7/100 - Loss: 2.041   lengthscale: 0.273 outputscale: 39.876  noise: 0.000
# Iter 7/100 - Loss: 2.040   lengthscale: 0.301 outputscale: 42.041  noise: 0.000
# Iter 7/100 - Loss: 2.040   lengthscale: 0.302 outputscale: 42.342  noise: 0.000
# Iter 7/100 - Loss: 2.039   lengthscale: 0.305 outputscale: 43.031  noise: 0.000
# Iter 7/100 - Loss: 2.038   lengthscale: 0.308 outputscale: 43.722  noise: 0.000
# Iter 7/100 - Loss: 2.037   lengthscale: 0.311 outputscale: 44.381  noise: 0.000
# Iter 7/100 - Loss: 2.037   lengthscale: 0.315 outputscale: 45.042  noise: 0.000
# Iter 7/100 - Loss: 2.036   lengthscale: 0.318 outputscale: 45.672  noise: 0.000
# Iter 7/100 - Loss: 2.036   lengthscale: 0.321 outputscale: 46.297  noise: 0.000
# Iter 7/100 - Loss: 2.035   lengthscale: 0.324 outputscale: 46.889  noise: 0.000
# Iter 7/100 - Loss: 2.035   lengthscale: 0.327 outputscale: 47.476  noise: 0.000
# Iter 7/100 - Loss: 2.034   lengthscale: 0.329 outputscale: 48.020  noise: 0.000
# inside optimizer: i =  7
# Iter 8/100 - Loss: 2.034   lengthscale: 0.332 outputscale: 48.572  noise: 0.000
# Iter 8/100 - Loss: 2.034   lengthscale: 0.334 outputscale: 49.062  noise: 0.000
# Iter 8/100 - Loss: 2.034   lengthscale: 0.337 outputscale: 49.595  noise: 0.000
# Iter 8/100 - Loss: 2.034   lengthscale: 0.338 outputscale: 50.047  noise: 0.000
# Iter 8/100 - Loss: 2.033   lengthscale: 0.341 outputscale: 50.557  noise: 0.000
# Iter 8/100 - Loss: 2.033   lengthscale: 0.343 outputscale: 50.971  noise: 0.000
# Iter 8/100 - Loss: 2.033   lengthscale: 0.345 outputscale: 51.381  noise: 0.000
# Iter 8/100 - Loss: 2.033   lengthscale: 0.346 outputscale: 51.735  noise: 0.000
# Iter 8/100 - Loss: 2.033   lengthscale: 0.348 outputscale: 52.075  noise: 0.000
# Iter 8/100 - Loss: 2.033   lengthscale: 0.349 outputscale: 52.382  noise: 0.000
# Iter 8/100 - Loss: 2.033   lengthscale: 0.350 outputscale: 52.671  noise: 0.000
# Iter 8/100 - Loss: 2.033   lengthscale: 0.352 outputscale: 52.936  noise: 0.000
# Iter 8/100 - Loss: 2.033   lengthscale: 0.353 outputscale: 53.183  noise: 0.000
# Iter 8/100 - Loss: 2.033   lengthscale: 0.354 outputscale: 53.409  noise: 0.000
# Iter 8/100 - Loss: 2.033   lengthscale: 0.355 outputscale: 53.618  noise: 0.000
# Iter 8/100 - Loss: 2.033   lengthscale: 0.355 outputscale: 53.809  noise: 0.000
# Iter 8/100 - Loss: 2.033   lengthscale: 0.356 outputscale: 53.986  noise: 0.000
# Iter 8/100 - Loss: 2.033   lengthscale: 0.357 outputscale: 54.147  noise: 0.000
# Iter 8/100 - Loss: 2.033   lengthscale: 0.357 outputscale: 54.294  noise: 0.000
# Iter 8/100 - Loss: 2.033   lengthscale: 0.358 outputscale: 54.429  noise: 0.000
# inside optimizer: i =  8
# Iter 9/100 - Loss: 2.033   lengthscale: 0.358 outputscale: 54.552  noise: 0.000
# Iter 9/100 - Loss: 2.033   lengthscale: 0.359 outputscale: 54.664  noise: 0.000
# Iter 9/100 - Loss: 2.033   lengthscale: 0.359 outputscale: 54.766  noise: 0.000
# Iter 9/100 - Loss: 2.033   lengthscale: 0.360 outputscale: 54.859  noise: 0.000
# Iter 9/100 - Loss: 2.033   lengthscale: 0.360 outputscale: 54.943  noise: 0.000
# Iter 9/100 - Loss: 2.033   lengthscale: 0.360 outputscale: 55.020  noise: 0.000
# Iter 9/100 - Loss: 2.033   lengthscale: 0.361 outputscale: 55.090  noise: 0.000
# Iter 9/100 - Loss: 2.033   lengthscale: 0.361 outputscale: 55.152  noise: 0.000
# Iter 9/100 - Loss: 2.033   lengthscale: 0.361 outputscale: 55.210  noise: 0.000
# Iter 9/100 - Loss: 2.033   lengthscale: 0.361 outputscale: 55.261  noise: 0.000
# Iter 9/100 - Loss: 2.033   lengthscale: 0.362 outputscale: 55.308  noise: 0.000
# Iter 9/100 - Loss: 2.033   lengthscale: 0.362 outputscale: 55.350  noise: 0.000
# Iter 9/100 - Loss: 2.033   lengthscale: 0.362 outputscale: 55.389  noise: 0.000
# Iter 9/100 - Loss: 2.033   lengthscale: 0.362 outputscale: 55.423  noise: 0.000
# Iter 9/100 - Loss: 2.033   lengthscale: 0.362 outputscale: 55.454  noise: 0.000
# Iter 9/100 - Loss: 2.033   lengthscale: 0.362 outputscale: 55.482  noise: 0.000
# Iter 9/100 - Loss: 2.033   lengthscale: 0.362 outputscale: 55.508  noise: 0.000
# Iter 9/100 - Loss: 2.033   lengthscale: 0.363 outputscale: 55.531  noise: 0.000
# Iter 9/100 - Loss: 2.033   lengthscale: 0.363 outputscale: 55.552  noise: 0.000
# Iter 9/100 - Loss: 2.033   lengthscale: 0.363 outputscale: 55.570  noise: 0.000
# inside optimizer: i =  9
# Iter 10/100 - Loss: 2.033   lengthscale: 0.363 outputscale: 55.587  noise: 0.000
# Iter 10/100 - Loss: 2.033   lengthscale: 0.363 outputscale: 55.602  noise: 0.000
# Iter 10/100 - Loss: 2.033   lengthscale: 0.363 outputscale: 55.616  noise: 0.000
# Iter 10/100 - Loss: 2.033   lengthscale: 0.363 outputscale: 55.628  noise: 0.000
# Iter 10/100 - Loss: 2.033   lengthscale: 0.363 outputscale: 55.639  noise: 0.000
# Iter 10/100 - Loss: 2.033   lengthscale: 0.363 outputscale: 55.650  noise: 0.000
# Iter 10/100 - Loss: 2.033   lengthscale: 0.363 outputscale: 55.658  noise: 0.000
# Iter 10/100 - Loss: 2.033   lengthscale: 0.363 outputscale: 55.667  noise: 0.000
# Iter 10/100 - Loss: 2.033   lengthscale: 0.363 outputscale: 55.674  noise: 0.000
# Iter 10/100 - Loss: 2.033   lengthscale: 0.363 outputscale: 55.681  noise: 0.000
# Iter 10/100 - Loss: 2.033   lengthscale: 0.363 outputscale: 55.687  noise: 0.000
# Iter 10/100 - Loss: 2.033   lengthscale: 0.363 outputscale: 55.693  noise: 0.000
# Iter 10/100 - Loss: 2.033   lengthscale: 0.363 outputscale: 55.698  noise: 0.000
# Iter 10/100 - Loss: 2.033   lengthscale: 0.363 outputscale: 55.702  noise: 0.000
# Iter 10/100 - Loss: 2.033   lengthscale: 0.363 outputscale: 55.705  noise: 0.000
# Iter 10/100 - Loss: 2.033   lengthscale: 0.363 outputscale: 55.710  noise: 0.000
# Iter 10/100 - Loss: 2.033   lengthscale: 0.363 outputscale: 55.712  noise: 0.000
# Iter 10/100 - Loss: 2.033   lengthscale: 0.363 outputscale: 55.715  noise: 0.000
# Iter 10/100 - Loss: 2.033   lengthscale: 0.363 outputscale: 55.718  noise: 0.000
# Iter 10/100 - Loss: 2.033   lengthscale: 0.363 outputscale: 55.721  noise: 0.000
# inside optimizer: i =  10
# Iter 11/100 - Loss: 2.033   lengthscale: 0.363 outputscale: 55.722  noise: 0.000
# Iter 11/100 - Loss: 2.033   lengthscale: 0.363 outputscale: 55.724  noise: 0.000
# Iter 11/100 - Loss: 2.033   lengthscale: 0.363 outputscale: 55.726  noise: 0.000
# Iter 11/100 - Loss: 2.033   lengthscale: 0.363 outputscale: 55.728  noise: 0.000
# inside optimizer: i =  11
# Iter 12/100 - Loss: 2.033   lengthscale: 0.363 outputscale: 55.728  noise: 0.000
# Iter 12/100 - Loss: 2.033   lengthscale: 0.363 outputscale: 55.729  noise: 0.000
# inside optimizer: i =  12
# Iter 13/100 - Loss: 2.033   lengthscale: 0.363 outputscale: 55.729  noise: 0.000
# ...
# Iter 17/100 - Loss: -2.402   lengthscale: 0.100 outputscale: 13.421  noise: 0.000
# inside optimizer: i =  17
# Iter 18/100 - Loss: -2.402   lengthscale: 0.100 outputscale: 13.421  noise: 0.000
# Iter 18/100 - Loss: -2.402   lengthscale: 0.100 outputscale: 13.421  noise: 0.000
# Iter 18/100 - Loss: -2.402   lengthscale: 0.100 outputscale: 13.421  noise: 0.000
# Iter 18/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.421  noise: 0.000
# Iter 18/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.421  noise: 0.000
# Iter 18/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.421  noise: 0.000
# Iter 18/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.421  noise: 0.000
# Iter 18/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.421  noise: 0.000
# Iter 18/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.421  noise: 0.000
# Iter 18/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.421  noise: 0.000
# Iter 18/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.421  noise: 0.000
# Iter 18/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.421  noise: 0.000
# Iter 18/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.421  noise: 0.000
# Iter 18/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.421  noise: 0.000
# Iter 18/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.421  noise: 0.000
# Iter 18/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.421  noise: 0.000
# Iter 18/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.421  noise: 0.000
# Iter 18/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.421  noise: 0.000
# Iter 18/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.421  noise: 0.000
# Iter 18/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.421  noise: 0.000
# inside optimizer: i =  18
# Iter 19/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.421  noise: 0.000
# Iter 19/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.421  noise: 0.000
# Iter 19/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.421  noise: 0.000
# Iter 19/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.421  noise: 0.000
# Iter 19/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.421  noise: 0.000
# Iter 19/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.421  noise: 0.000
# Iter 19/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.421  noise: 0.000
# Iter 19/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.421  noise: 0.000
# Iter 19/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.421  noise: 0.000
# Iter 19/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.421  noise: 0.000
# Iter 19/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.421  noise: 0.000
# Iter 19/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.421  noise: 0.000
# Iter 19/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.421  noise: 0.000
# Iter 19/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.421  noise: 0.000
# Iter 19/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.421  noise: 0.000
# Iter 19/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.421  noise: 0.000
# Iter 19/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.421  noise: 0.000
# Iter 19/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.421  noise: 0.000
# Iter 19/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.421  noise: 0.000
# Iter 19/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.421  noise: 0.000
# inside optimizer: i =  19
# Iter 20/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.421  noise: 0.000
# Iter 20/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.426  noise: 0.000
# Iter 20/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.477  noise: 0.000
# Iter 20/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.523  noise: 0.000
# Iter 20/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.565  noise: 0.000
# Iter 20/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.603  noise: 0.000
# Iter 20/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.638  noise: 0.000
# Iter 20/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.670  noise: 0.000
# Iter 20/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.699  noise: 0.000
# Iter 20/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.726  noise: 0.000
# Iter 20/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.749  noise: 0.000
# Iter 20/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.771  noise: 0.000
# Iter 20/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.791  noise: 0.000
# Iter 20/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.809  noise: 0.000
# Iter 20/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.825  noise: 0.000
# Iter 20/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.840  noise: 0.000
# Iter 20/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.853  noise: 0.000
# Iter 20/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.865  noise: 0.000
# Iter 20/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.876  noise: 0.000
# Iter 20/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.885  noise: 0.000
# inside optimizer: i =  20
# Iter 21/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.894  noise: 0.000
# Iter 21/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.902  noise: 0.000
# Iter 21/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.909  noise: 0.000
# Iter 21/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.916  noise: 0.000
# Iter 21/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.922  noise: 0.000
# Iter 21/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.927  noise: 0.000
# Iter 21/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.932  noise: 0.000
# Iter 21/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.936  noise: 0.000
# Iter 21/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.940  noise: 0.000
# Iter 21/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.943  noise: 0.000
# Iter 21/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.946  noise: 0.000
# Iter 21/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.949  noise: 0.000
# Iter 21/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.952  noise: 0.000
# Iter 21/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.954  noise: 0.000
# Iter 21/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.956  noise: 0.000
# Iter 21/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.958  noise: 0.000
# Iter 21/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.960  noise: 0.000
# Iter 21/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.961  noise: 0.000
# Iter 21/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.962  noise: 0.000
# Iter 21/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.964  noise: 0.000
# inside optimizer: i =  21
# Iter 22/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.965  noise: 0.000
# Iter 22/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.966  noise: 0.000
# Iter 22/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.967  noise: 0.000
# Iter 22/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.967  noise: 0.000
# Iter 22/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.968  noise: 0.000
# Iter 22/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.969  noise: 0.000
# Iter 22/100 - Loss: -2.403   lengthscale: 0.100 outputscale: 13.969  noise: 0.000
# Iter 22/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  22
# Iter 23/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  23
# Iter 24/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  24
# Iter 25/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  25
# Iter 26/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  26
# Iter 27/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  27
# Iter 28/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  28
# Iter 29/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  29
# Iter 30/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  30
# Iter 31/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  31
# Iter 32/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  32
# Iter 33/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  33
# Iter 34/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  34
# Iter 35/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  35
# Iter 36/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  36
# Iter 37/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  37
# Iter 38/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  38
# Iter 39/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  39
# Iter 40/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  40
# Iter 41/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  41
# Iter 42/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  42
# Iter 43/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  43
# Iter 44/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  44
# Iter 45/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  45
# Iter 46/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  46
# Iter 47/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  47
# Iter 48/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  48
# Iter 49/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  49
# Iter 50/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  50
# Iter 51/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  51
# Iter 52/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  52
# Iter 53/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  53
# Iter 54/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  54
# Iter 55/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  55
# Iter 56/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  56
# Iter 57/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  57
# Iter 58/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  58
# Iter 59/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  59
# Iter 60/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  60
# Iter 61/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  61
# Iter 62/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  62
# Iter 63/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  63
# Iter 64/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  64
# Iter 65/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  65
# Iter 66/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  66
# Iter 67/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  67
# Iter 68/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  68
# Iter 69/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  69
# Iter 70/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  70
# Iter 71/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  71
# Iter 72/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  72
# Iter 73/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  73
# Iter 74/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  74
# Iter 75/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  75
# Iter 76/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  76
# Iter 77/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  77
# Iter 78/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  78
# Iter 79/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  79
# Iter 80/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  80
# Iter 81/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  81
# Iter 82/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  82
# Iter 83/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  83
# Iter 84/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  84
# Iter 85/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  85
# Iter 86/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  86
# Iter 87/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  87
# Iter 88/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  88
# Iter 89/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  89
# Iter 90/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  90
# Iter 91/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  91
# Iter 92/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  92
# Iter 93/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  93
# Iter 94/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  94
# Iter 95/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  95
# Iter 96/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  96
# Iter 97/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  97
# Iter 98/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  98
# Iter 99/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# inside optimizer: i =  99
# Iter 100/100 - Loss: -5.424   lengthscale: 0.100 outputscale: 13.970  noise: 0.000
# info_gain
# taking new x. best non-existent index 0 [0.55555556]
# Iteration 9. Evaluted function 11 to values: [[0.62451083]]

# %%
x_candidate = [-0.25]
x_candidate = [X_grid[41]]
print('x_candidate ', x_candidate)
from excursion.optimize import core
thresholds = [-np.inf] + scandetails.thresholds + [np.inf]
print('thresholds ', thresholds)
acqval = core.info_gain_gpytorch(x_candidate, gps, thresholds, scandetails.meanX) 
print('acqval(x_candidate) ', acqval)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-8ad014103ed0> in <module>()
#       1 x_candidate = [-0.25]
# ----> 2 x_candidate = [X_grid[41]]
#       3 print('x_candidate ', x_candidate)
#       4 from excursion.optimize import core
#       5 thresholds = [-np.inf] + scandetails.thresholds + [np.inf]
#
# IndexError: index 41 is out of bounds for dimension 0 with size 20
